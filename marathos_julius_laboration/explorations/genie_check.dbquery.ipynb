-- %%
USE CATALOG marathos;

USE SCHEMA gold;

-- SELECT
--   DATE_TRUNC('month', `event_date`) AS month,
--   COUNT(DISTINCT `event_name`) AS event_count
-- FROM
--   `marathos`.`gold`.`mart_distance_events`
-- WHERE
--   `event_date` IS NOT NULL
--   AND DATE_TRUNC('month', `event_date`) >= '1990-01-01'
-- GROUP BY
--   DATE_TRUNC('month', `event_date`)
-- ORDER BY
--   month


--   SELECT
--   'Distance' AS event_type,
--   MIN(athlete_average_speed) AS minimum_speed,
--   MAX(athlete_average_speed) AS maximum_speed,
--   AVG(athlete_average_speed) AS average_speed
-- FROM marathos.gold.mart_distance_events

-- UNION ALL

-- SELECT
--   'Time' AS event_type,
--   MIN(athlete_average_speed) AS minimum_speed,
--   MAX(athlete_average_speed) AS maximum_speed,
--   AVG(athlete_average_speed) AS average_speed
-- FROM marathos.gold.mart_time_events;

-- SELECT
--   athlete_gender,
--   COUNT(*) AS total_results,
--   ROUND(
--     COUNT(*) * 100.0 / SUM(COUNT(*)) OVER (),
--     2
--   ) AS percentage
-- FROM
--   marathos.gold.mart_time_events
-- GROUP BY
--   athlete_gender
-- ORDER BY
--   total_results DESC;

-- SELECT
--   athlete_gender,
--   COUNT(*) AS total_results,
--   ROUND(
--     COUNT(*) * 100.0 / SUM(COUNT(*)) OVER (),
--     2
--   ) AS percentage
-- FROM
--   marathos.gold.mart_distance_events
-- GROUP BY
--   athlete_gender
-- ORDER BY
--   total_results DESC;
